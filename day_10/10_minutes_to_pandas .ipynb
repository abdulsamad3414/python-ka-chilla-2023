# %% [markdown]
# # Data Wrangling and Data visualization

# %%
import numpy as np 
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
#pandas libraray also use for date funtion and date is also a  data type like integer,string bool
dates = pd.date_range("20130101", periods=50)
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28',
#                '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01',
#                '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05',
#                '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09',
#                '2013-02-10', '2013-02-11', '2013-02-12', '2013-02-13',
#                '2013-02-14', '2013-02-15', '2013-02-16', '2013-02-17',
#                '2013-02-18', '2013-02-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
# make a data frame and assign a random values in it 
df = pd.DataFrame(np.random.randn(50, 4), index=dates, columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.165910  1.618067 -1.249101 -1.043139
# 2013-01-02 -0.921804  0.276206  1.098793  0.542016
# 2013-01-03  0.380602  1.367553 -0.999714 -0.273974
# 2013-01-04  2.172674 -0.097861  0.707542  0.433926
# 2013-01-05 -1.172642 -0.447542  2.098140  2.225972
# 2013-01-06  0.198525  0.806032  0.070004 -1.450600
# 2013-01-07 -0.178814 -0.365943  1.844322 -0.621058
# 2013-01-08 -0.262472 -0.017121  1.513635 -0.338281
# 2013-01-09  0.238934 -0.871795 -0.382117  0.574672
# 2013-01-10 -0.145029 -1.081986 -1.447202 -0.200408
# 2013-01-11  1.124534  1.141045  0.067664 -0.962576
# 2013-01-12  0.828398  0.308090 -0.098353  2.493051
# 2013-01-13  0.208359  0.674509  3.204966 -0.340514
# 2013-01-14  1.556688 -0.193280  1.014572  2.146335
# 2013-01-15 -1.708369  1.337718  0.362529 -0.062004
# 2013-01-16  0.916703 -0.367637  0.297081  0.864058
# 2013-01-17  1.047448 -0.245539 -0.570933 -1.208059
# ...

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20130102"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df.head()
# Out:
#                    A         B         C         D
# 2013-01-01 -0.165910  1.618067 -1.249101 -1.043139
# 2013-01-02 -0.921804  0.276206  1.098793  0.542016
# 2013-01-03  0.380602  1.367553 -0.999714 -0.273974
# 2013-01-04  2.172674 -0.097861  0.707542  0.433926
# 2013-01-05 -1.172642 -0.447542  2.098140  2.225972

# %%
df.tail()
# Out:
#                    A         B         C         D
# 2013-02-15 -1.549522  1.595027 -0.626610 -0.043893
# 2013-02-16  1.463822  0.716999 -0.359359  0.555812
# 2013-02-17  1.071133  1.700202  0.565947  1.292865
# 2013-02-18  0.029738 -0.414791  2.095770 -1.162946
# 2013-02-19 -0.352820 -2.316661  0.591129 -0.338456

# %%
df.index
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10', '2013-01-11', '2013-01-12',
#                '2013-01-13', '2013-01-14', '2013-01-15', '2013-01-16',
#                '2013-01-17', '2013-01-18', '2013-01-19', '2013-01-20',
#                '2013-01-21', '2013-01-22', '2013-01-23', '2013-01-24',
#                '2013-01-25', '2013-01-26', '2013-01-27', '2013-01-28',
#                '2013-01-29', '2013-01-30', '2013-01-31', '2013-02-01',
#                '2013-02-02', '2013-02-03', '2013-02-04', '2013-02-05',
#                '2013-02-06', '2013-02-07', '2013-02-08', '2013-02-09',
#                '2013-02-10', '2013-02-11', '2013-02-12', '2013-02-13',
#                '2013-02-14', '2013-02-15', '2013-02-16', '2013-02-17',
#                '2013-02-18', '2013-02-19'],
#               dtype='datetime64[ns]', freq='D')

# %%
df2.index
# Out:
# Index([0, 1, 2, 3], dtype='int64')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01 -0.165910  1.618067 -1.249101 -1.043139
# 2013-01-02 -0.921804  0.276206  1.098793  0.542016
# 2013-01-03  0.380602  1.367553 -0.999714 -0.273974
# 2013-01-04  2.172674 -0.097861  0.707542  0.433926
# 2013-01-05 -1.172642 -0.447542  2.098140  2.225972
# 2013-01-06  0.198525  0.806032  0.070004 -1.450600
# 2013-01-07 -0.178814 -0.365943  1.844322 -0.621058
# 2013-01-08 -0.262472 -0.017121  1.513635 -0.338281
# 2013-01-09  0.238934 -0.871795 -0.382117  0.574672
# 2013-01-10 -0.145029 -1.081986 -1.447202 -0.200408
# 2013-01-11  1.124534  1.141045  0.067664 -0.962576
# 2013-01-12  0.828398  0.308090 -0.098353  2.493051
# 2013-01-13  0.208359  0.674509  3.204966 -0.340514
# 2013-01-14  1.556688 -0.193280  1.014572  2.146335
# 2013-01-15 -1.708369  1.337718  0.362529 -0.062004
# 2013-01-16  0.916703 -0.367637  0.297081  0.864058
# 2013-01-17  1.047448 -0.245539 -0.570933 -1.208059
# ...

# %%
#in this no index 
df.to_numpy()
# Out:
# array([[-0.16590957,  1.61806709, -1.24910099, -1.04313944],
#        [-0.92180449,  0.27620624,  1.0987929 ,  0.54201568],
#        [ 0.38060202,  1.36755332, -0.99971368, -0.27397396],
#        [ 2.17267412, -0.09786056,  0.70754217,  0.43392608],
#        [-1.17264174, -0.44754209,  2.09814035,  2.22597165],
#        [ 0.19852525,  0.80603228,  0.07000359, -1.45059982],
#        [-0.17881424, -0.36594346,  1.84432213, -0.62105782],
#        [-0.26247173, -0.01712088,  1.51363474, -0.33828115],
#        [ 0.23893431, -0.87179473, -0.38211749,  0.57467185],
#        [-0.14502855, -1.08198582, -1.44720168, -0.20040753],
#        [ 1.12453393,  1.14104483,  0.06766429, -0.9625756 ],
#        [ 0.82839806,  0.30809042, -0.09835259,  2.49305086],
#        [ 0.20835853,  0.67450856,  3.20496568, -0.34051409],
#        [ 1.55668827, -0.19327981,  1.0145723 ,  2.14633455],
#        [-1.70836862,  1.33771838,  0.36252918, -0.06200416],
# ...

# %%
df.describe()
# Out:
#                A          B          C          D
# count  50.000000  50.000000  50.000000  50.000000
# mean   -0.039295   0.192810   0.274979  -0.047534
# std     1.066387   1.034995   0.981867   1.038454
# min    -2.850845  -2.316661  -1.447202  -2.459992
# 25%    -0.905155  -0.443317  -0.399258  -0.735165
# 50%     0.107669   0.206776   0.292115  -0.055649
# 75%     0.784959   0.885882   0.834809   0.569957
# max     2.172674   2.058140   3.204966   2.493051

# %%
df.T
# Out:
#    2013-01-01  2013-01-02  2013-01-03  2013-01-04  2013-01-05  2013-01-06  \
# A   -0.165910   -0.921804    0.380602    2.172674   -1.172642    0.198525
# B    1.618067    0.276206    1.367553   -0.097861   -0.447542    0.806032
# C   -1.249101    1.098793   -0.999714    0.707542    2.098140    0.070004
# D   -1.043139    0.542016   -0.273974    0.433926    2.225972   -1.450600
#
#    2013-01-07  2013-01-08  2013-01-09  2013-01-10  ...  2013-02-10  \
# A   -0.178814   -0.262472    0.238934   -0.145029  ...    0.844560
# B   -0.365943   -0.017121   -0.871795   -1.081986  ...    2.058140
# C    1.844322    1.513635   -0.382117   -1.447202  ...    0.737796
# D   -0.621058   -0.338281    0.574672   -0.200408  ...    0.673328
#
#    2013-02-11  2013-02-12  2013-02-13  2013-02-14  2013-02-15  2013-02-16  \
# A    0.654643   -0.937891   -1.539960    0.135383   -1.549522    1.463822
# B    1.016477    1.320071    0.815850   -2.023747    1.595027    0.716999
# ...

# %%
# from D TO A
# axies is equal to 1 so change in columns and 0 change in rows this is fixwd
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2013-02-19 -0.352820 -2.316661  0.591129 -0.338456
# 2013-02-18  0.029738 -0.414791  2.095770 -1.162946
# 2013-02-17  1.071133  1.700202  0.565947  1.292865
# 2013-02-16  1.463822  0.716999 -0.359359  0.555812
# 2013-02-15 -1.549522  1.595027 -0.626610 -0.043893
# 2013-02-14  0.135383 -2.023747 -0.620759 -0.049294
# 2013-02-13 -1.539960  0.815850  0.368467  0.031721
# 2013-02-12 -0.937891  1.320071 -0.681942  1.118858
# 2013-02-11  0.654643  1.016477  1.573454  1.246445
# 2013-02-10  0.844560  2.058140  0.737796  0.673328
# 2013-02-09  0.468499 -0.596386  0.996246 -0.774803
# 2013-02-08 -0.511094 -1.094782  0.230947 -2.459992
# 2013-02-07 -2.850845 -0.838890 -0.320393  0.425919
# 2013-02-06  0.236547 -0.430642  0.787882 -0.383733
# 2013-02-05 -1.270084 -0.319768 -0.028044 -1.131869
# 2013-02-04  1.637596 -1.506963  0.491513  0.650038
# 2013-02-03  0.316468  0.678104 -0.375152 -1.025907
# ...

# %%
df.sort_values(by="B").head()
# Out:
#                    A         B         C         D
# 2013-02-19 -0.352820 -2.316661  0.591129 -0.338456
# 2013-02-14  0.135383 -2.023747 -0.620759 -0.049294
# 2013-01-27 -1.229524 -1.600195 -0.343649 -0.301990
# 2013-02-04  1.637596 -1.506963  0.491513  0.650038
# 2013-02-08 -0.511094 -1.094782  0.230947 -2.459992

# %%
df.sort_values(by="A")   # in this no multi values can be inserted in it
# Out:
#                    A         B         C         D
# 2013-02-07 -2.850845 -0.838890 -0.320393  0.425919
# 2013-01-28 -2.140200  0.242419 -0.404972  0.154798
# 2013-01-15 -1.708369  1.337718  0.362529 -0.062004
# 2013-02-15 -1.549522  1.595027 -0.626610 -0.043893
# 2013-02-13 -1.539960  0.815850  0.368467  0.031721
# 2013-02-05 -1.270084 -0.319768 -0.028044 -1.131869
# 2013-01-27 -1.229524 -1.600195 -0.343649 -0.301990
# 2013-01-05 -1.172642 -0.447542  2.098140  2.225972
# 2013-02-12 -0.937891  1.320071 -0.681942  1.118858
# 2013-01-30 -0.932923  0.658448  1.306436 -0.743649
# 2013-01-31 -0.932063 -0.473247  0.925906  0.222162
# 2013-01-02 -0.921804  0.276206  1.098793  0.542016
# 2013-02-01 -0.911120  0.171133  1.027297  0.007102
# 2013-01-25 -0.887257  0.841138 -0.937753 -0.709715
# 2013-01-26 -0.771560  1.870643  0.712718  0.284607
# 2013-02-08 -0.511094 -1.094782  0.230947 -2.459992
# 2013-01-19 -0.470262  0.083150 -1.122823  0.098945
# ...

# %%
# in this there are four columns in and and range will be write like this 0 to 3
df[0:3]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.165910  1.618067 -1.249101 -1.043139
# 2013-01-02 -0.921804  0.276206  1.098793  0.542016
# 2013-01-03  0.380602  1.367553 -0.999714 -0.273974

# %%
# first number show row and 2nd number show column like this (2,3) 2 rows and 3 columns 
df.iloc[0:2,1:3]
# Out:
#                    B         C
# 2013-01-01  1.618067 -1.249101
# 2013-01-02  0.276206  1.098793

# %%
df.iloc[:3,0:4]
# Out:
#                    A         B         C         D
# 2013-01-01 -0.165910  1.618067 -1.249101 -1.043139
# 2013-01-02 -0.921804  0.276206  1.098793  0.542016
# 2013-01-03  0.380602  1.367553 -0.999714 -0.273974

# %%
df.iloc[0:3,2:3]
# Out:
#                    C
# 2013-01-01 -1.249101
# 2013-01-02  1.098793
# 2013-01-03 -0.999714

# %%
# lock the index here
df.loc[dates[0]]
# Out:
# A   -0.165910
# B    1.618067
# C   -1.249101
# D   -1.043139
# Name: 2013-01-01 00:00:00, dtype: float64

# %%
df.loc[:, ["A", "B"]] # this is string type data
# Out:
#                    A         B
# 2013-01-01 -0.165910  1.618067
# 2013-01-02 -0.921804  0.276206
# 2013-01-03  0.380602  1.367553
# 2013-01-04  2.172674 -0.097861
# 2013-01-05 -1.172642 -0.447542
# 2013-01-06  0.198525  0.806032
# 2013-01-07 -0.178814 -0.365943
# 2013-01-08 -0.262472 -0.017121
# 2013-01-09  0.238934 -0.871795
# 2013-01-10 -0.145029 -1.081986
# 2013-01-11  1.124534  1.141045
# 2013-01-12  0.828398  0.308090
# 2013-01-13  0.208359  0.674509
# 2013-01-14  1.556688 -0.193280
# 2013-01-15 -1.708369  1.337718
# 2013-01-16  0.916703 -0.367637
# 2013-01-17  1.047448 -0.245539
# 2013-01-18  1.057754  0.900797
# 2013-01-19 -0.470262  0.083150
# 2013-01-20  1.833079  0.509357
# 2013-01-21  0.354333  1.278218
# 2013-01-22  0.406587 -0.003911
# 2013-01-23 -0.364328  0.476437
# 2013-01-24  0.123696 -0.668234
# 2013-01-25 -0.887257  0.841138
# 2013-01-26 -0.771560  1.870643
# 2013-01-27 -1.229524 -1.600195
# 2013-01-28 -2.140200  0.242419
# 2013-01-29  0.091641  1.778210
# ...

# %%
#this is index 3 values and transpose automatically 
df.iloc[3]
# Out:
# A    2.172674
# B   -0.097861
# C    0.707542
# D    0.433926
# Name: 2013-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5,0:2]
# Out:
#                    A         B
# 2013-01-04  2.172674 -0.097861
# 2013-01-05 -1.172642 -0.447542

# %%
df=pd.read_excel('D:\python ka chilla 2023\day_9\kashti.xlsx')
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# <>:1: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\Abdul-Samad\AppData\Local\Temp\ipykernel_1848\2296294219.py:1: SyntaxWarning: invalid escape sequence '\p'
#   df=pd.read_excel('D:\python ka chilla 2023\day_9\kashti.xlsx')
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# ...

# %%
df.shape
# Out:
# (891, 13)

# %%
# sampling data we took random 100 rows from the dataset 
df.sample(100)
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 841         841          842         0       2
# 529         529          530         0       2
# 122         122          123         0       2
# 337         337          338         1       1
# 19           19           20         1       3
# ..          ...          ...       ...     ...
# 607         607          608         1       1
# 417         417          418         1       2
# 777         777          778         1       3
# 306         306          307         1       1
# 615         615          616         1       2
#
#                                 Name     Sex   Age  SibSp  Parch       Ticket  \
# 841         Mudd, Mr. Thomas Charles    male  16.0      0      0  S.O./P.P. 3
# 529      Hocking, Mr. Richard George    male  23.0      2      1        29104
# 122             Nasser, Mr. Nicholas    male  32.5      1      0       237736
# 337  Burns, Miss. Elizabeth Margaret  female  41.0      0      0        16966
# ...

# %% [markdown]
# # Data Filtering using conditional operators

# %%
# Titanic ka dataset jis ma age ka column seletect kyea or use kyea conditional operators like >< jis may age 5 say less ho wo dataset
df[df['Age']<5]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 7             7            8         0       3
# 10           10           11         1       3
# 16           16           17         0       3
# 43           43           44         1       2
# 63           63           64         0       3
# 78           78           79         1       2
# 119         119          120         0       3
# 164         164          165         0       3
# 171         171          172         0       3
# 172         172          173         1       3
# 183         183          184         1       2
# 184         184          185         1       3
# 193         193          194         1       2
# 205         205          206         0       3
# 261         261          262         1       3
# 297         297          298         0       1
# 305         305          306         1       1
# 340         340          341         1       2
# 348         348          349         1       3
# ...

# %%
# children data jo less then 1 ho
df[df['Age']<1]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 78           78           79         1       2
# 305         305          306         1       1
# 469         469          470         1       3
# 644         644          645         1       3
# 755         755          756         1       2
# 803         803          804         1       3
# 831         831          832         1       2
#
#                                 Name     Sex   Age  SibSp  Parch  Ticket  \
# 78     Caldwell, Master. Alden Gates    male  0.83      0      2  248738
# 305   Allison, Master. Hudson Trevor    male  0.92      1      2  113781
# 469    Baclini, Miss. Helene Barbara  female  0.75      2      1    2666
# 644           Baclini, Miss. Eugenie  female  0.75      2      1    2666
# 755        Hamalainen, Master. Viljo    male  0.67      1      1  250649
# 803  Thomas, Master. Assad Alexander    male  0.42      0      1    2625
# 831  Richards, Master. George Sibley    male  0.83      1      1   29106
# ...

# %%
df[df['Age']>60]
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 33           33           34         0       2
# 54           54           55         0       1
# 96           96           97         0       1
# 116         116          117         0       3
# 170         170          171         0       1
# 252         252          253         0       1
# 275         275          276         1       1
# 280         280          281         0       3
# 326         326          327         0       3
# 438         438          439         0       1
# 456         456          457         0       1
# 483         483          484         1       3
# 493         493          494         0       1
# 545         545          546         0       1
# 555         555          556         0       1
# 570         570          571         1       2
# 625         625          626         0       1
# 630         630          631         1       1
# 672         672          673         0       2
# ...
