# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# import dataset
kashti=sns.load_dataset('titanic')
kashti
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
kashti.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
kashti.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
kashti.survived.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='survived'>

# %%
plt.scatter(data=kashti, x='age',y='fare')

# %%
sns.scatterplot(data=kashti, x='age',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
sns.barplot(data=kashti,x='sex',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.scatterplot(data=kashti,x='sex',y='fare',hue='pclass')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
#in pair plot survived make plot with all columns ,pclass will make plot with all columns ,sex will make plot with all columns ....and etc
kashti.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
#draw one variable to another variable
sns.pairplot(kashti)

# %%
#all numeric data plot a histogram plot
#all data is good and set if below graph is showing normality graph
kashti.hist()
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
#change the bins() size like below
kashti.hist(bins=15)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
# for sizing and dimensions
kashti.hist(bins=10 ,figsize=(7,8))
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
# remove backgrid
kashti.hist(grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
kashti.hist(bins=10,figsize=(6,9),grid=False)
# Out:
# array([[<Axes: title={'center': 'survived'}>,
#         <Axes: title={'center': 'pclass'}>],
#        [<Axes: title={'center': 'age'}>,
#         <Axes: title={'center': 'sibsp'}>],
#        [<Axes: title={'center': 'parch'}>,
#         <Axes: title={'center': 'fare'}>]], dtype=object)

# %%
sns.boxplot(data=kashti,x='sex',y='fare',hue='who')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
sns.boxenplot(data=kashti, x='sex', y='fare')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>

# %%
# Assignmet how to change x and y axis titles?
sns.boxenplot(data=kashti,x='who',y='class')
# Out:
# <Axes: xlabel='who', ylabel='class'>

# %%
sns.boxplot(data=kashti,x='embark_town',y='pclass')
# Out:
# <Axes: xlabel='embark_town', ylabel='pclass'>

# %%
sns.scatterplot(data=kashti,x='who',y='embarked')
# Out:
# <Axes: xlabel='who', ylabel='embarked'>

# %%
# stripplot is the combination of bar and scatterplot
sns.stripplot(data=kashti,x='who',y='embarked')
# Out:
# <Axes: xlabel='who', ylabel='embarked'>

# %%
sns.stripplot(data=kashti,x='sex',y='fare', hue='class')
# Out:
# <Axes: xlabel='sex', ylabel='fare'>
